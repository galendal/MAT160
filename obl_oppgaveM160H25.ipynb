# %% [markdown]
# # 🌀 Vindkraft – Obligatorisk innlevering i MAT160 H2025.
#
# **Navn:** _fyll inn ditt navn her_
#
# Dette er den obligatoriske innleveringen i MAT160 høsten 2025. Fristen for innlevering er **torsdag 23. oktober kl. 23:59**.
#
# Bruk [denne](https://colab.research.google.com/github/galendal/MAT160/blob/main/obl_oppgaveM160H25.ipynb) Jupyter-filen som utgangspunkt. Lagre en kopi på din egen maskin, og utfør oppgavene ved å legge til nye celler. Når du er ferdig, leverer du filen via Mitt UiB, og bruker ditt eget navn som filnavn.
#
# I denne oppgaven skal du bruke vinddata til å utforske hvordan matematikk kan brukes til å modellere og analysere vindkraftproduksjon. Oppgaven er delt inn i sju deler. Den siste delen er en refleksjon over oppgaven og din bruk av AI i arbeidet. Her forventes mer enn én setning — bruk gjerne anledningen til å tenke gjennom hvordan AI har hjulpet deg, og hva du har lært.
#
# Det er helt greit å samarbeide, men _alle må levere sin egen besvarelse_. Du kan også bruke AI-verktøy, men jeg forventer at du er ærlig om bruken og reflekterer godt i den siste delen.

# %% [markdown]
# ## 🔹 Forberedelse: Last inn vind-data
# Dataen vil bli lastet inn i noe som kalles Pandas, se https://pandas.pydata.org for mer informasjon.
# ### Meteostat data portalen.
#
# Vi skal bruke et åpent datasett som inneholder relativt ferske værdata fra hele verden. Se https://meteostat.net/no for en generell introduksjon, og https://dev.meteostat.net/python/ for python-biblioteket.
#
# Vi installerer først biblioteket (om nødvendig), og laster det deretter inn:

# %%
# %pip install meteostat
# Import Meteostat library
from meteostat import Stations, Daily, Hourly
# %pip install folium
import folium
from IPython.display import display
import pandas as pd
from datetime import datetime
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# La oss se på værstasjonene som er nærmest **Bergen** som ligger på $(lat,lon)=(60.392993, 5.324138) $

# %%
bergen_txt = "Bergen, Norway"
bergen_latlon = (60.392993, 5.324138)  # Latitude and Longitude for Bergen, Norway
latlon = bergen_latlon
number_of_stations = 25 # Number of stations to fetch
# Get nearby weather stations
stations = Stations()
stations = stations.nearby(latlon[0], latlon[1])
station = stations.fetch(number_of_stations)
# Display nearby stations
display(station.style.set_caption(f"Nearby Weather Stations for {bergen_txt}").background_gradient(cmap='Blues'))
# Out:
# <style type="text/css">
# #T_cc979_row0_col5, #T_cc979_row7_col15, #T_cc979_row12_col6, #T_cc979_row22_col6 {
#   background-color: #75b4d8;
#   color: #000000;
# }
# #T_cc979_row0_col6 {
#   background-color: #5fa6d1;
#   color: #f1f1f1;
# }
# #T_cc979_row0_col7, #T_cc979_row1_col7, #T_cc979_row4_col7, #T_cc979_row9_col7, #T_cc979_row11_col7, #T_cc979_row12_col7, #T_cc979_row17_col7, #T_cc979_row22_col7, #T_cc979_row24_col7 {
#   background-color: #084d96;
#   color: #f1f1f1;
# }
# #T_cc979_row0_col15, #T_cc979_row10_col7, #T_cc979_row15_col7, #T_cc979_row20_col5, #T_cc979_row24_col6 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# #T_cc979_row1_col5, #T_cc979_row9_col15 {
#   background-color: #60a7d2;
#   color: #f1f1f1;
# }
# #T_cc979_row1_col6 {
#   background-color: #4292c6;
#   color: #f1f1f1;
# }
# #T_cc979_row1_col15 {
#   background-color: #d3e4f3;
#   color: #000000;
# }
# #T_cc979_row2_col5 {
#   background-color: #74b3d8;
#   color: #000000;
# }
# #T_cc979_row2_col6 {
#   background-color: #3585bf;
#   color: #f1f1f1;
# }
# #T_cc979_row2_col7 {
#   background-color: #084387;
#   color: #f1f1f1;
# }
# #T_cc979_row2_col15 {
#   background-color: #c7dbef;
#   color: #000000;
# }
# #T_cc979_row3_col5 {
#   background-color: #b2d2e8;
#   color: #000000;
# }
# #T_cc979_row3_col6 {
#   background-color: #68acd5;
#   color: #f1f1f1;
# }
# #T_cc979_row3_col7, #T_cc979_row5_col7, #T_cc979_row7_col7, #T_cc979_row8_col7, #T_cc979_row13_col7, #T_cc979_row20_col7, #T_cc979_row23_col7 {
#   background-color: #084c95;
#   color: #f1f1f1;
# }
# #T_cc979_row3_col15 {
#   background-color: #b5d4e9;
#   color: #000000;
# }
# #T_cc979_row4_col5 {
#   background-color: #4d99ca;
#   color: #f1f1f1;
# }
# #T_cc979_row4_col6 {
#   background-color: #2d7dbb;
#   color: #f1f1f1;
# }
# #T_cc979_row4_col15 {
#   background-color: #a0cbe2;
#   color: #000000;
# }
# #T_cc979_row5_col5 {
#   background-color: #7ab6d9;
#   color: #000000;
# }
# #T_cc979_row5_col6 {
#   background-color: #2373b6;
#   color: #f1f1f1;
# }
# #T_cc979_row5_col15 {
#   background-color: #9dcae1;
#   color: #000000;
# }
# #T_cc979_row6_col5 {
#   background-color: #3383be;
#   color: #f1f1f1;
# }
# #T_cc979_row6_col6 {
#   background-color: #3484bf;
#   color: #f1f1f1;
# }
# #T_cc979_row6_col7, #T_cc979_row18_col7, #T_cc979_row20_col15 {
#   background-color: #084a91;
#   color: #f1f1f1;
# }
# #T_cc979_row6_col15 {
#   background-color: #7fb9da;
#   color: #000000;
# }
# #T_cc979_row7_col5 {
#   background-color: #ccdff1;
#   color: #000000;
# }
# #T_cc979_row7_col6 {
#   background-color: #5da5d1;
#   color: #f1f1f1;
# }
# #T_cc979_row8_col5, #T_cc979_row11_col6 {
#   background-color: #1f6eb3;
#   color: #f1f1f1;
# }
# #T_cc979_row8_col6 {
#   background-color: #5ba3d0;
#   color: #f1f1f1;
# }
# #T_cc979_row8_col15, #T_cc979_row17_col6 {
#   background-color: #66abd4;
#   color: #f1f1f1;
# }
# #T_cc979_row9_col5 {
#   background-color: #81badb;
#   color: #000000;
# }
# #T_cc979_row9_col6 {
#   background-color: #125ea6;
#   color: #f1f1f1;
# }
# #T_cc979_row10_col5 {
#   background-color: #4e9acb;
#   color: #f1f1f1;
# }
# #T_cc979_row10_col6 {
#   background-color: #d1e2f3;
#   color: #000000;
# }
# #T_cc979_row10_col15 {
#   background-color: #3787c0;
#   color: #f1f1f1;
# }
# #T_cc979_row11_col5 {
#   background-color: #d9e7f5;
#   color: #000000;
# }
# #T_cc979_row11_col15, #T_cc979_row12_col15 {
#   background-color: #2575b7;
#   color: #f1f1f1;
# }
# #T_cc979_row12_col5 {
#   background-color: #08519c;
#   color: #f1f1f1;
# }
# #T_cc979_row13_col5 {
#   background-color: #ebf3fb;
#   color: #000000;
# }
# #T_cc979_row13_col6 {
#   background-color: #72b2d8;
#   color: #f1f1f1;
# }
# #T_cc979_row13_col15 {
#   background-color: #1c6ab0;
#   color: #f1f1f1;
# }
# #T_cc979_row14_col5 {
#   background-color: #71b1d7;
#   color: #f1f1f1;
# }
# #T_cc979_row14_col6, #T_cc979_row14_col7, #T_cc979_row16_col6 {
#   background-color: #083b7c;
#   color: #f1f1f1;
# }
# #T_cc979_row14_col15 {
#   background-color: #1b69af;
#   color: #f1f1f1;
# }
# #T_cc979_row15_col5 {
#   background-color: #3080bd;
#   color: #f1f1f1;
# }
# #T_cc979_row15_col6 {
#   background-color: #d6e5f4;
#   color: #000000;
# }
# #T_cc979_row15_col15 {
#   background-color: #1967ad;
#   color: #f1f1f1;
# }
# #T_cc979_row16_col5 {
#   background-color: #4b98ca;
#   color: #f1f1f1;
# }
# #T_cc979_row16_col7 {
#   background-color: #08326e;
#   color: #f1f1f1;
# }
# #T_cc979_row16_col15 {
#   background-color: #1562a9;
#   color: #f1f1f1;
# }
# #T_cc979_row17_col5 {
#   background-color: #f3f8fe;
#   color: #000000;
# }
# #T_cc979_row17_col15 {
#   background-color: #0e58a2;
#   color: #f1f1f1;
# }
# #T_cc979_row18_col5 {
#   background-color: #083e81;
#   color: #f1f1f1;
# }
# #T_cc979_row18_col6 {
#   background-color: #3a8ac2;
#   color: #f1f1f1;
# }
# #T_cc979_row18_col15, #T_cc979_row19_col15 {
#   background-color: #084f99;
#   color: #f1f1f1;
# }
# #T_cc979_row19_col5 {
#   background-color: #99c7e0;
#   color: #000000;
# }
# #T_cc979_row19_col6, #T_cc979_row19_col7, #T_cc979_row22_col5, #T_cc979_row24_col15 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_cc979_row20_col6 {
#   background-color: #82bbdb;
#   color: #000000;
# }
# #T_cc979_row21_col5 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_cc979_row21_col6 {
#   background-color: #084488;
#   color: #f1f1f1;
# }
# #T_cc979_row21_col7 {
#   background-color: #084285;
#   color: #f1f1f1;
# }
# #T_cc979_row21_col15 {
#   background-color: #084082;
#   color: #f1f1f1;
# }
# #T_cc979_row22_col15 {
#   background-color: #083776;
#   color: #f1f1f1;
# }
# #T_cc979_row23_col5 {
#   background-color: #08316d;
#   color: #f1f1f1;
# }
# #T_cc979_row23_col6 {
#   background-color: #94c4df;
#   color: #000000;
# }
# #T_cc979_row23_col15 {
#   background-color: #083471;
#   color: #f1f1f1;
# }
# #T_cc979_row24_col5 {
#   background-color: #64a9d3;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_cc979">
#   <caption>Nearby Weather Stations for Bergen, Norway</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_cc979_level0_col0" class="col_heading level0 col0" >name</th>
#       <th id="T_cc979_level0_col1" class="col_heading level0 col1" >country</th>
#       <th id="T_cc979_level0_col2" class="col_heading level0 col2" >region</th>
#       <th id="T_cc979_level0_col3" class="col_heading level0 col3" >wmo</th>
#       <th id="T_cc979_level0_col4" class="col_heading level0 col4" >icao</th>
#       <th id="T_cc979_level0_col5" class="col_heading level0 col5" >latitude</th>
#       <th id="T_cc979_level0_col6" class="col_heading level0 col6" >longitude</th>
#       <th id="T_cc979_level0_col7" class="col_heading level0 col7" >elevation</th>
#       <th id="T_cc979_level0_col8" class="col_heading level0 col8" >timezone</th>
#       <th id="T_cc979_level0_col9" class="col_heading level0 col9" >hourly_start</th>
#       <th id="T_cc979_level0_col10" class="col_heading level0 col10" >hourly_end</th>
#       <th id="T_cc979_level0_col11" class="col_heading level0 col11" >daily_start</th>
#       <th id="T_cc979_level0_col12" class="col_heading level0 col12" >daily_end</th>
#       <th id="T_cc979_level0_col13" class="col_heading level0 col13" >monthly_start</th>
#       <th id="T_cc979_level0_col14" class="col_heading level0 col14" >monthly_end</th>
#       <th id="T_cc979_level0_col15" class="col_heading level0 col15" >distance</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >id</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#       <th class="blank col3" >&nbsp;</th>
#       <th class="blank col4" >&nbsp;</th>
#       <th class="blank col5" >&nbsp;</th>
#       <th class="blank col6" >&nbsp;</th>
#       <th class="blank col7" >&nbsp;</th>
#       <th class="blank col8" >&nbsp;</th>
#       <th class="blank col9" >&nbsp;</th>
#       <th class="blank col10" >&nbsp;</th>
#       <th class="blank col11" >&nbsp;</th>
#       <th class="blank col12" >&nbsp;</th>
#       <th class="blank col13" >&nbsp;</th>
#       <th class="blank col14" >&nbsp;</th>
#       <th class="blank col15" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc979_level0_row0" class="row_heading level0 row0" >01317</th>
#       <td id="T_cc979_row0_col0" class="data row0 col0" >Bergen / Florida</td>
#       <td id="T_cc979_row0_col1" class="data row0 col1" >NO</td>
#       <td id="T_cc979_row0_col2" class="data row0 c

# %% [markdown]
# La oss se på dem i et kart.

# %%
# Create a map centered at the specified location
m = folium.Map(location=latlon, zoom_start=7)

# Add markers for each station
for idx, row in station.iterrows():
    folium.Marker(
        location=[row['latitude'], row['longitude']],
        popup=f"{row['name']} (WMO: {row['wmo']})",
        tooltip=row['name']
    ).add_to(m)
# Add a circle marker for the specified location
folium.CircleMarker(
        location=[latlon[0], latlon[1]],
        popup=f"Our location: {bergen_txt}",
        tooltip=bergen_txt,
        color='red'
    ).add_to(m)
folium.Marker(
        location=[latlon[0], latlon[1]],
        popup=f"Our location: {bergen_txt}",
        tooltip=bergen_txt,
        icon=folium.Icon(icon='cloud', color='red', icon_color='white', prefix='fa')
    ).add_to(m)
# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03b876b65d4b81ae938457baf687ee3b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03b876b65d4b81ae938457baf687ee3b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03b876b65d4b81ae938457baf687ee3b = L.map(
#                 &quot;map_03b876b65d4b81ae938457baf687ee3b&quot;,
#                 {
#                     center: [60.392993, 5.324138],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 7,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_91b4cc29f9d461ffa0c42010b6bcb177 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_91b4cc29f9d461ffa0c42010b6bcb177.addTo(map_03b876b65d4b81ae938457baf687ee3b);
#
#
#             var marker_7dd55519eb076d2caa6e6ba01bc13fb1 = L.marker(
#                 [60.3833, 5.3333],
#                 {
# }
#             ).addTo(map_03b876b65d4b81ae938457baf687ee3b);
#
#
#         var popup_326543deb1ab43c975cf3b4542bb040a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9014f20a5519534fda8b2ce6b91becf = $(`&lt;div id=&quot;html_f9014f20a5519534fda8b2ce6b91becf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Bergen / Florida (WMO: 01317)&lt;/div&gt;`)[0];
#                 popup_326543deb1ab43c975cf3b4542bb040a.setContent(html_f9014f20a5519534fda8b2ce6b91becf);
#
#
#
#         marker_7dd55519eb076d2caa6e6ba01bc13fb1.bindPopup(popup_326543deb1ab43c975cf3b4542bb040a)
#         ;
#
#
#
#
#             marker_7dd55519eb076d2caa6e6ba01bc13fb1.bindTooltip(
#                 `&lt;div&gt;
#                      Bergen / Florida
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_d83275e2e35716d915651663a4018efe = L.marker(
#                 [60.5206, 5.7247],
#                 {
# }
#             ).addTo(map_03b876b65d4b81ae938457baf687ee3b);
#
#
#         var popup_154e4077c31d6d30f719dcf188eaa454 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5c076e6307b90a6e7ac5ff8e1f3dc6b1 = $(`&lt;div id=&quot;html_5c076e6307b90a6e7ac5ff8e1f3dc6b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Fossmark / Stanghelle (WMO: 01314)&lt;/div&gt;`)[0];
#                 popup_154e4077c31d6d30f719dcf188eaa454.setContent(html_5c076e6307b90a6e7ac5ff8e1f3dc6b1);
#
#
#
#         marker_d83275e2e35716d915651663a4018efe.bindPopup(popup_154e4077c31d6d30f719dcf188eaa454)
#         ;
#
#
#
#
#             marker_d83275e2e35716d915651663a4018efe.bindTooltip(
#                 `&lt;div&gt;
#                      Fossmark / Stanghelle
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_56b7ded2698348b2ae2c1ac7b584826c = L.marker(
#                 [60.3886, 5.9639],
#                 {
# }
#             ).addTo(map_03b876b65d4b81ae938457baf687ee3b);
#
#
#         var popup_8972b4e6b144f532da06e41a944a7cbb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_28eaa5cd23289e815a32558cfb6fff2e = $(`&lt;div id=&quot;html_28eaa5cd23289e815a32558cfb6fff2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kvamskogen-jonshogdi / Kleivi (WMO: 01327)&lt;/div&gt;`)[0];
#                 popup_8972b4e6b144f532da06e41a944a7cbb.setContent(html_28eaa5cd23289e815a32558cfb6fff2e);
#
#
#
#         marker_56b7ded2698348b2ae2c1ac7b584826c.bindPopup(popup_8972b4e6b144f532da06e41a944a7cbb)
#         ;
#
#
#
#
#             marker_56b7ded2698348b2ae2c1ac7b584826c.bindTooltip(
#                 `&lt;div&gt;
#                      Kvamskogen-jonshogdi / Kleivi
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var marker_88359e00e7462ed3006e8928d15f562d = L.marker(
#                 [60.0167, 5.2058],
#                 {
# }
#             ).addTo(map_03b876b65d4b81ae938457baf687ee3b);
#
#
#         var popup_74fc354acb65b01b478f459aaa63c0f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83f940bdeb56aeb469e2a5090be1b1c1 = $(`&lt;div id=&quot;html_83f940bdeb56aeb469e2a5090be1b1c1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Upsanger Lake / Bekkjarvik (WMO: 01418)&lt;/div&gt;`)[0];
#                 popup_74fc354acb65b01b478f459aaa63c0f9.setContent(html_83f940bdeb56aeb469e2a5090be1b1c1);

# %%
# Select stations with names containing "Bergen", "Dyranut", "Utsira", and "Oseberg"
selected_names = ["Bergen", "Utsira", "Oseberg","Dyranut"]
selected_stations = station[station['name'].str.contains('|'.join(selected_names), case=False, na=False)]

# Display the selected stations
display(selected_stations)
# Out:
#                      name country region    wmo  icao  latitude  longitude  \
# id
# 01317    Bergen / Florida      NO     HO  01317  <NA>   60.3833     5.3333
# 01352     Dyranut Maurset      NO     46  01352  <NA>   60.1839     7.4814
# 01403          Utsira Fyr      NO     RO  01403  <NA>   59.3000     4.8833
# ENOA0  Oseberg / Oseberga      NO   <NA>   <NA>  ENOA   60.4919     2.8273
#
#        elevation     timezone hourly_start hourly_end daily_start  daily_end  \
# id
# 01317       12.0  Europe/Oslo   1973-01-01 2025-03-21  1957-01-01 2025-08-24
# 01352     1250.0  Europe/Oslo   2004-01-07 2025-03-21  2008-12-23 2021-08-23
# 01403       55.0  Europe/Oslo   1928-01-02 2025-09-30  1943-01-01 2025-08-24
# ENOA0       15.0  Europe/Oslo   1990-10-19 2025-09-25  2009-09-02 2022-03-21
#
#       monthly_start monthly_end       distance
# id
# 01317    1957-01-01  2022-01-01    1189.574091
# 01352    2013-01-01  2019-01-01  121137.129957
# 01403    1943-01-01  2022-01-01  124003.779827
# ENOA0    2020-01-01  2021-01-01  137389.550360

# %% [markdown]
# ### Hvilke data finnes på serveren?
# Definerer en tidsperiode fra februar 2022. Du kan velge en annen periode hvis du vil.
#
# La oss lese inn data fra de valgte stasjonene og se hva vi finner.

# %%
# Define the time period for data retrieval
start = datetime(2022, 2, 21) # Start date: February 21, 2022
end = datetime(2022, 3, 1) # End date: March 1, 2022

# Get station IDs for the three selected stations
station_ids = selected_stations.index.tolist()

# Fetch hourly data for each station and store in a dictionary
hourly_data = {}
for sid in station_ids:
    data = Hourly(sid, start, end).fetch()
    hourly_data[sid] = data

# Display the first few rows for each station
for sid, data in hourly_data.items():
    print(f"\nHourly data for station {sid} ({selected_stations.loc[sid, 'name']}):")
    display(data.head())
# Out:
# Hourly data for station 01317 (Bergen / Florida):
#                      temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt   pres  \
# time
# 2022-02-21 00:00:00   1.9   1.8  99.0   2.4   NaN  150.0  10.1  27.0  971.7
# 2022-02-21 01:00:00   2.6   1.1  90.0   0.4   NaN  139.0   7.6  25.2  972.5
# 2022-02-21 02:00:00   2.7   1.4  91.0   0.2   NaN  135.0  12.2  19.1  973.0
# 2022-02-21 03:00:00   2.6   2.0  96.0   0.2   NaN  129.0   6.1  14.4  972.5
# 2022-02-21 04:00:00   2.8   2.4  97.0   0.1   NaN  136.0   5.8  11.9  973.0
#
#                      tsun  coco
# time
# 2022-02-21 00:00:00   NaN   NaN
# 2022-02-21 01:00:00   NaN   NaN
# 2022-02-21 02:00:00   NaN   NaN
# 2022-02-21 03:00:00   NaN   NaN
# 2022-02-21 04:00:00   NaN   NaN
# Hourly data for station 01352 (Dyranut Maurset):
#                      temp  dwpt  rhum  prcp  snow  wdir  wspd  wpgt   pres  \
# time
# 2022-02-21 00:00:00  -8.5  -9.4  93.0   0.2   NaN  90.0   8.6  18.7  975.5
# 2022-02-21 01:00:00  -8.9  -9.8  93.0   0.2   NaN  85.0  10.8  14.4  975.6
# 2022-02-21 02:00:00  -9.2 -10.3  92.0   0.2   NaN  62.0   8.3  14.8  975.5
# 2022-02-21 03:00:00  -9.7 -10.8  92.0   0.2   NaN  55.0   7.9  13.3  975.7
# 2022-02-21 04:00:00 -10.0 -11.1  92.0   0.1   NaN  22.0   5.0   9.7  976.0
#
#                      tsun  coco
# time
# 2022-02-21 00:00:00   NaN   NaN
# 2022-02-21 01:00:00   NaN   NaN
# 2022-02-21 02:00:00   NaN   NaN
# 2022-02-21 03:00:00   NaN   NaN
# 2022-02-21 04:00:00   NaN   NaN
# Hourly data for station 01403 (Utsira Fyr):
#                      temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt   pres  \
# time
# 2022-02-21 00:00:00   4.7   2.9  88.0   NaN   NaN  309.0  22.0  35.0  972.4
# 2022-02-21 01:00:00   4.7   2.6  86.0   0.0   NaN  295.0  40.3  49.0  972.8
# 2022-02-21 02:00:00   4.5   1.9  83.0   0.0   NaN  319.0  27.7  62.0  973.4
# 2022-02-21 03:00:00   5.0   2.4  83.0   0.0   NaN  302.0  36.0  46.0  973.8
# 2022-02-21 04:00:00   4.9   2.8  86.0   0.0   NaN  294.0  37.0  49.0  974.2
#
#                      tsun  coco
# time
# 2022-02-21 00:00:00   NaN  18.0
# 2022-02-21 01:00:00   NaN  18.0
# 2022-02-21 02:00:00   NaN  18.0
# 2022-02-21 03:00:00   NaN  18.0
# 2022-02-21 04:00:00   NaN  18.0
# Hourly data for station ENOA0 (Oseberg / Oseberga):
#                      temp  dwpt  rhum  prcp  snow   wdir  wspd  wpgt   pres  \
# time
# 2022-02-21 00:00:00   6.0   2.1  76.0   0.0   NaN  250.0  35.3  50.0  970.7
# 2022-02-21 01:00:00   6.3   2.0  74.0   0.0   NaN  275.0  34.9  51.5  971.3
# 2022-02-21 02:00:00   5.0   0.9  75.0   0.0   NaN  290.0  38.9  45.7  971.7
# 2022-02-21 03:00:00   6.0   2.1  76.0   0.0   NaN  290.0  35.3  43.9  972.4
# 2022-02-21 04:00:00   6.0   2.1  76.0   0.0   NaN  290.0  35.3  34.9  973.6
#
#                      tsun  coco
# time
# 2022-02-21 00:00:00   NaN   NaN
# 2022-02-21 01:00:00   NaN   NaN
# 2022-02-21 02:00:00   NaN   NaN
# 2022-02-21 03:00:00   NaN   NaN
# 2022-02-21 04:00:00   NaN   NaN

# %% [markdown]
# Hastighetene, middelvind (wspd) og høyeste vindkast (wpgt) er i $km/t$, vi må regne om til $m/s$.

# %%
# Regn om vindhastighet (wspd) og vindkast (wpgt) fra km/t til m/s i data
for sid, data in hourly_data.items():
    data['wspd'] = data['wspd'] * 1000 / 3600  # Convert km/h to m/s
    data['wpgt'] = data['wpgt'] * 1000 / 3600  # Convert km/h to m/s
    hourly_data[sid] = data

# %% [markdown]
# La oss se på dataene.

# %%
fig, axs = plt.subplots(3, 1, figsize=(12, 12), sharex=True)
# 1. Vindhastighet (wspd)
for sid in station_ids:
    df_station = hourly_data[sid]
    axs[0].plot(df_station.index, df_station['wspd'], marker='o', label=selected_stations.loc[sid, 'name'])

axs[0].set_xlabel('Tid')
axs[0].set_ylabel('Vindhastighet (m/s)')
axs[0].set_title('Vindhastighet over tid for tre stasjoner')
axs[0].legend()
axs[0].grid(True)

# 2. Vindkast (wpgt)
for sid in station_ids:
    df_station = hourly_data[sid]
    axs[1].plot(df_station.index, df_station['wpgt'], marker='o', label=selected_stations.loc[sid, 'name'])
axs[1].set_ylabel('Vindkast (m/s)')
axs[1].set_title('Vindkast over tid for tre stasjoner')
axs[1].legend()
axs[1].grid(True)

# 3. Lufttrykk (pres) 
for sid in station_ids:
    df_station = hourly_data[sid]
    axs[2].plot(df_station.index, df_station['pres'], marker='o', label=selected_stations.loc[sid, 'name'])
axs[2].set_ylabel('Trykk (hPa)')
axs[2].set_title('Lufttrykk over tid for tre stasjoner')
axs[2].legend()
axs[2].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 🔹 Del 1: Bruk av numerisk derivasjon
# I denne delen skal du bruke numerisk derivasjon for å undersøke hvordan vindhastighet endrer seg over tid.
#
# **Oppgave:**
#
# **1.** Lag egne Python-funksjoner som beregner den numeriske deriverte (endringsrate) for vindhastighet basert på tidsseriedataene.
# - Implementer foroverdifferanse og sentraldifferanse.
# - Funksjonene skal ta inn to lister eller arrays: én for tid og én for vindhastighet.
#
# **2.** Test funksjonene dine med en kjent funksjon.
#
# **3.** Plott de numeriske deriverte for vindhastighet for en av stasjonene: Bruk samme figur for å vise både foroverdifferanse og sentraldifferanse. Merk aksene tydelig og legg til en forklarende figurtekst.
#
# **3.** Diskuter forskjellene mellom de to metodene i figuren.
#
# **(Valgfritt)** Glatt dataserien før derivasjon: eksempel _df['gliding_mean'] = df['value'].rolling(window=3).mean()_, se også https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.rolling.html

# %% [markdown]
# ## 🔹 Del 2: Ikke-lineær ligning
# Vindkraft er energi som utvinnes fra bevegelsen i luftmassene. Når vinden blåser gjennom rotorbladene på en vindturbin, overføres noe av vindens kinetiske energi til rotoren, som igjen driver en generator og produserer elektrisk kraft.
#
# Effekten som kan hentes ut fra vinden, er gitt ved formelen:
# $$P(v) = \frac{1}{2} \cdot \rho \cdot A \cdot C_p \cdot v^3$$
#
# I oppgaven bruk:
# - $ \rho $ er luftens tetthet (kg/m³), bruk: $ \rho = 1.225 \text{ kg/m}^3 $
# - $ A $ er arealet vinden treffer (arealet av rotoren, $A = \pi r^2$), bruk: $ r = 40 \text{ m} \Rightarrow A = \pi r^2 $
# - $ C_p $ er effektkoeffisienten, som beskriver hvor stor andel av vindens energi som faktisk kan omdannes til elektrisitet (teoretisk maksimum er Betz-grensen, ca. 0.59, men praktisk ofte 0.4), bruk $ C_p = 0.4 $
# - $ v $ er vindhastigheten (m/s)
#
# Formelen viser at effekten øker med tredje potens av vindhastigheten, noe som betyr at små endringer i vind gir store utslag i effekt.
#
# **Oppgave:** Finn vindhastigheten som gir en effekt på 500 kW. Bruk Halveringsmetoden-, Newton- og Sekant-metodene. Sammenlign dine resultater med _scipy.optimize.fsolve_ og finn feilen for metodene.

# %% [markdown]
# ## 🔹 Del 3: Numerisk integrasjon, beregn potensiel energiproduksjon.
#
#
# I denne oppgaven skal du selv kode opp numeriske integrasjonsmetoder for å beregne total potensiell energi produsert av vindkraft for de fire utvalgte stasjonene i perioden.
#
# **Oppgave:**
# 1. Skriv dine egne Python-funksjoner for numerisk integrasjon med:
#     - Trapesmetoden
#     - Midtpunktsmetoden
#     - Simpsons metode (forutsetter partall antall intervaller)
# 2. Test funksjonene dine på et enkelt datasett der du kjenner fasiten, for å sjekke at de gir riktige resultater. En mulighet er å bruke en funksjon du kjenner integralet til.
# 3. For hver av de fire stasjonene, bruk vindhastighetsdataene til å beregne effekt $P(v)$ for hver time, og integrer effekten over perioden med alle tre metodene.
# 4. Sammenlign resultatene fra de ulike metodene og diskuter eventuelle forskjeller.
# 5. Kan du forklare eventuelle forskjeller mellom stasjonene.
#
# **Tips:**
# - Husk å bruke riktig tidsenhet (timer) i integrasjonen slik at du får energien i kWh.
# - Du kan bruke `hourly_data[sid]['wspd']` for vindhastighet (i m/s) og `hourly_data[sid].index` for tidspunkter.

# %% [markdown]
# ## 🔹 Del 4: Interpolasjon
# Her skal du:
#
# 1. Ta ut hvert tredje datapunkt fra vindhastighetsserien.
# 2. Lag to interpolasjonsrutiner: én med Lagrange-polynomer og én med splines.
# 3. Interpoler vindhastigheten for alle tidspunkter mellom punktene, og sammenlign med de faktiske målingene.
# 4. Plott både de opprinnelige dataene, de utvalgte punktene og de to interpolerte kurvene. Forklar hvorfor du har valgt å presentere dem på denne måten.
# 5. For en av stasjonene, bruke delte differanser for å se om feilen endrer seg for de to første utelatte punktene i tidsserien hvis du legger til nye data punkter fra tidsserien med hvert tredje datapunkt.
#
# **Tips:**
# - Beregn og vis gjerne feilen (f.eks. RMSE) mellom de interpolerte verdiene og de faktiske målingene.

# %% [markdown]
# ## 🔹 Del 5: Lineær modelltilpasning
#
# For hver stasjon, plott et spredningsdiagram (scatterplot) mellom middelvind (`wspd`) og vindkast (`wpgt`), og tilpass en rett linje (lineær modell) med minste kvadraters metode (least squares). Vis både datapunktene og den tilpassede linjen i figuren. Hvor god er en slik model for de fire stasjonene?

# %% [markdown]
# ## 🔹 Del 6:
#
# 1. **Oppgave:**
#     a) Sett en maksgrense for vindkast (`wpgt_max`, f.eks. 25 m/s).
#     b) Regn ut hvor mye energi som produseres i perioden dersom turbinen skrus av (dvs. effekt = 0) i alle tidsintervaller der `wpgt` overstiger denne grensen.
#     c) Diskuter hvordan dette påvirker energiproduksjonen sammenlignet med uten grense.
#
# 2. **Ekstra utfordring:**
#     Vi kan ikke alltid måle eller forutsi vindkast nøyaktig.
#     a) Kan du bruke modellen som predikerer vindkast (`wpgt`) ut fra middelvind (`wspd`) til å estimere når turbinen bør skrus av, basert på middelvind alene (f.eks. skrus av når predikert gust overstiger grensen).
#     b) Sammenlign energiproduksjonen og diskuter forskjellen mellom å bruke faktisk gust og predikert gust for styring av turbinen.
#
# **Tips:**
# - Bruk NumPy eller pandas til å sette effekt til 0 der `wpgt` (eller predikert `wpgt`) er over grensen.
# - Visualiser gjerne hvilke tidspunkter turbinen er aktiv/inaktiv.
# - Diskuter usikkerheten ved å bruke en slik modell i praksis.

# %% [markdown]
# ## 🔹 Del 7: Refleksjon
#
# **Oppgave:**
#
# 1. Reflekter over hva du har lært gjennom å løse denne oppgaven.
#     - Hvilke matematiske og programmeringstekniske ferdigheter har du fått brukt og utviklet?
#     - Var det noen deler av oppgaven du syntes var spesielt utfordrende eller interessante?
#
# 2. Reflekter over bruken av AI i arbeidet med oppgaven.
#     - Har du brukt AI-verktøy (for eksempel ChatGPT, Copilot eller lignende) i arbeidet?
#     - Beskriv konkret hva du har brukt AI til (for eksempel idéutvikling, feilsøking, koding, forklaringer, dokumentasjon osv.).
#     - Diskuter fordeler og eventuelle ulemper ved å bruke AI som støtte i slike oppgaver.
#     - Hvordan påvirker bruken av AI din egen læring og forståelse?
